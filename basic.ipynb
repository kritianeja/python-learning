# %%
#basics class

# %%
"""hello 
this is a demo """
# Out:
# 'hello \nthis is a demo '

# %% [markdown]
# #python

# %% [markdown]
# # python

# %% [markdown]
# # python

# %% [markdown]
# ## python

# %%
a=1
print(a)
# Out:
# 1

# %%
c=19.5
print(c)
# Out:
# 19.5

# %%
k="kriti"
print(k)
# Out:
# kriti

# %%
a=10
type(a)
# Out:
# int

# %%
b=11.99
type(b)
# Out:
# float

# %%
c="kriti"
type(c)
# Out:
# str

# %%
x=10
y=5
print(x+y)
# Out:
# 15

# %%
print(x-y)
# Out:
# 5

# %%
print(x/y)
# Out:
# 2.0

# %%
print(x//y)
# Out:
# 2

# %%
print(x%y)
# Out:
# 0

# %%
print(x**y)
# Out:
# 100000

# %%
print(x==y)
print(x!=y)
print(x>y)
print(x<y)
# Out:
# False
# True
# True
# False

# %%
print(x>=y)
print(x<=y)
# Out:
# True
# False

# %%
5>2 and 10>8
# Out:
# True

# %%
5>2 and 10<8
# Out:
# False

# %%
5>10 or 8>3
# Out:
# True

# %%
2>5 or 1>4
# Out:
# False

# %%
not(5>2)
# Out:
# False

# %%
not(5<2)
# Out:
# True

# %%
name="kriti"
"k" in name
# Out:
# True

# %%
"x" in name
# Out:
# False
