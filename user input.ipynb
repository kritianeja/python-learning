# %%
name=input("enter your name")
print("my name is",name)
# Out:
# enter your name kriti
# my name is kriti

# %%
age=int(input("enter your age"))
print("my age is",age)
# Out:
# enter your age 18
# my age is 18

# %%
age=float(input("enter your exact age"))
print("my age is",age)
# Out:
# enter your exact age 18.6
# my age is 18.6
