# %%
#write a program to check weather the number is positive or not

# %%
a=1334
if a>0:
    print("number is positive")
else:
    print("number is negatie")
# Out:
# number is positive

# %%
a=-98
if a<0:
    print("number is negative")
else:
    print("number is positive")
# Out:
# number is negative

# %%
num=int(input("enter the number "))
if a>0:
    print("number is positive")
else:
    print("number is negatie")
# Out:
# enter the number  -655
# number is negatie

# %%
#program to check if a number is even or odd

# %%
num=int(input("enter the number "))
if num%2==0:
    print("number is even")
else:
    print("number is odd")
# Out:
# enter the number  12
# number is even

# %%
num=int(input("enter the number "))
if num>0:
    print("number is positive")
elif num==0:
    print("number is zero")
else:
    print("number is negative")
# Out:
# enter the number  -99
# number is negative

# %%
a=int(input("enter first number "))
b=int(input("enter second number "))
if a>b:
    print("greatest number is",a)
else:
    print("greatest number is",b)
# Out:
# enter first number  44
# enter second number  1
# greatest number is 44

# %%
a=int(input("enter first number "))
b=int(input("enter second number "))
c=int(input("enter first number "))
if a>b and a>c:
    print("greatest number is",a)
elif b>a and b>c:
    print("greatest number is",b)
elif b==a and b==c:
    print("all numbers are equal")
else:
    print("greatest number is",c)
# Out:
# enter first number  3
# enter second number  2
# enter first number  1
# greatest number is 3

# %%
name=input("enter the name").lower()
if name[0] in 'aeiou':
    print("name is starting with a vowel")
else:
    print("name is starting with a consonant")
# Out:
# enter the name KRITI
# name is starting with a consonant

# %%
year=int(input("enter the year"))

if year%4==0 and year%100!=0:
    print("leap year")
elif year%400==0:
    print("leap year")
else:
    print("not a leap year")
# Out:
# enter the year 4000
# leap year

# %%
num=int(input("enter a number"))
if num%3==0 and num%5==0:
    print("number is divisible by both 3 and 5")
else:
    print("number is not divisible by 3 and 5")
# Out:
# enter a number 12
# number is not divisible by 3 and 5

# %%
marks=int(input("enter your marks"))
if marks>=90:
    print("A+")
9elif marks>=75:
    print("B+")
elif marks>=50:
    print("c+")
else:
    print("d")
# Out:
# enter your marks 102
# A+

# %%
age=int(input("enter your age "))
if age<18:
    print("minor")
elif age>18 and age<=59:
    print("adult")
else:
    print("senior citizen")
# Out:
# enter your age  45
# adult
