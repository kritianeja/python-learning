# %%
a=10
type(a)
# Out:
# int

# %%
a=3.6*a

# %%
a
# Out:
# 36.0

# %%
type(a)
# Out:
# float

# %%
b=23

# %%
type(b)
# Out:
# int

# %%
b=b+11.34

# %%
b
# Out:
# 34.34

# %%
type(b)
# Out:
# float

# %%
x=10

# %%
x=float(x)

# %%
type(x)
# Out:
# float

# %%
x=int(x)

# %%
type(x)
# Out:
# int

# %%
x=str(x)

# %%
type(x)
# Out:
# str
